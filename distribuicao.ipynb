# %%
import pandas as pd
import matplotlib.pyplot as mp

# %%
df = pd.read_csv("C:\\Users\\migro\\Desktop\\Programming\\interactive_dash\\Video_Games.csv")
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
genre_platform = pd.crosstab(df["Genre"], df["Platform"]).T
genre_platform
# Out:
# Genre     Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# Platform
# 2600          61          2         2     5         9      11       6
# 3DO            0          1         0     0         0       1       0
# 3DS          188         38        14    54        28      20      11
# DC             3         11        12     0         2       0       6
# DS           340        238        36   391        91     236      67
# GB             6          5         0     8        19      15       2
# GBA          167         38        23   110       142      41      64
# GC           101         20        42    36        73      13      63
# GEN            3          2         5     1         7       0       1
# GG             0          0         0     0         1       0       0
# N64           38          4        29    18        30      12      57
# NES           13          1         4     2        28      14       4
# ...

# %%
genre_plat = pd.DataFrame(genre_platform.sum(axis=0))
genre_plat["Total"] = genre_plat.values
genre_plat
# Out:
#                  0  Total
# Genre
# Action        3370   3370
# Adventure     1303   1303
# Fighting       849    849
# Misc          1750   1750
# Platform       888    888
# Puzzle         580    580
# Racing        1249   1249
# Role-Playing  1500   1500
# Shooter       1323   1323
# Simulation     874    874
# Sports        2348   2348
# Strategy       683    683

# %%
genre_plat["Total"].sum()
# Out:
# 16717
