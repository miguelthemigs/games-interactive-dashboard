# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\migro\\Desktop\\Programming\\interactive_dash\\Video_Games.csv")
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
df_ordenado = df.sort_values(["Critic_Score"]).head(10)
df_ordenado
# Out:
#                                       Name Platform  Year_of_Release  \
# 13690                         Ride to Hell      PS3           2013.0
# 10663  Leisure Suit Larry: Box Office Bust      PS3           2009.0
# 12823                         Ride to Hell     X360           2013.0
# 10016                             Rugby 15      PS4           2015.0
# 15345                        Balls of Fury      Wii           2007.0
# 9106                         Chicken Shoot       DS           2007.0
# 12132                            Anubis II      Wii           2007.0
# 7219               Nickelodeon Party Blast       XB           2002.0
# 1050                       Deal or No Deal       DS           2007.0
# 11443                       Ninjabread Man      Wii           2007.0
#
#            Genre               Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 13690     Racing             Deep Silver      0.02      0.01       0.0
# ...

# %%
df_ordenado = df_ordenado[["Name", "Critic_Score"]]
df_ordenado = df_ordenado[:-1]
df_ordenado
# Out:
#                                   Name  Critic_Score
# 1                       Ninjabread Man          20.0
# 2                      Deal or No Deal          20.0
# 3              Nickelodeon Party Blast          19.0
# 4                            Anubis II          19.0
# 5                        Chicken Shoot          19.0
# 6                        Balls of Fury          19.0
# 7                             Rugby 15          19.0
# 8                         Ride to Hell          19.0
# 9  Leisure Suit Larry: Box Office Bust          17.0

# %%
df_ordenado = df_ordenado.reset_index(drop=True)
df_ordenado = df_ordenado.loc[::-1]
df_ordenado = df_ordenado.reset_index(drop=True)
df_ordenado.index = df_ordenado.index.map(lambda x: x+1)
df_ordenado
# Out:
#                                   Name  Critic_Score
# 1  Leisure Suit Larry: Box Office Bust          17.0
# 2                         Ride to Hell          19.0
# 3                             Rugby 15          19.0
# 4                        Balls of Fury          19.0
# 5                        Chicken Shoot          19.0
# 6                            Anubis II          19.0
# 7              Nickelodeon Party Blast          19.0
# 8                      Deal or No Deal          20.0
# 9                       Ninjabread Man          20.0
